# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    # Your code here
    f.read("sample.txt")
    for i in

    pass

# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_804/1433391890.py in <cell line: 0>()
#      12     f.write("Data science is evolving. Python is versatile. Learning never stops.")
#      13
# ---> 14 print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
#
# /tmp/ipykernel_804/1433391890.py in top_k_words(filename, k)
#       4 def top_k_words(filename: str, k: int) -> list:
#       5     # Your code here
# ----> 6     f.read("sample.txt")
#       7
#       8     pass
#
# TypeError: argument should be integer or None, not 'str'

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
from IPython.core.application import catch_config_error
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        # TODO: store category-wise total
        expenses[category] = amount  # takes each value to dictionary list
        print(expenses)
        print(expenses.values())










    # TODO: calculate total expense
    total = sum(expenses.values())

    # TODO: find highest category
    highest_category = max(expenses.values())


    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()
# Out:
# Enter number of transactions: 2
# Food 200
# {'Food': 200.0}
# dict_values([200.0])
# Travel 500
# {'Food': 200.0, 'Travel': 500.0}
# dict_values([200.0, 500.0])
# Total Expense: 700.0
# Highest Category: 500.0
# Category-wise: {'Food': 200.0, 'Travel': 500.0}

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)


            # TODO: ignore negative values
            if num >= 0:
              data.append(num)

        except:
            # TODO: handle invalid values

            pass

    # TODO: calculate average
    avg =
    # TODO: find max
    max_val = max()

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)

clean_data()
# Out:
# Enter number of values: 4
# 1
# -2
# 3
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_804/487934498.py in <cell line: 0>()
#      28     print("Max:", max_val)
#      29
# ---> 30 clean_data()
#
# /tmp/ipykernel_804/487934498.py in clean_data()
#      21
#      22     # TODO: calculate average
# ---> 23     avg = data.sum()/n
#      24     # TODO: find max
#      25
#
# AttributeError: 'list' object has no attribute 'sum'
